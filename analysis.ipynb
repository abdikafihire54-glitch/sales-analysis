# %%
import pandas as pd
df = pd.read_csv("product_sales_dataset.csv")
df.head()
# Out:
#   Product_ID  Product_Name Category Price_USD Quantity_Sold Total_Sales_USD  \
# 0       1001      Lipstick   Beauty        26             7             182
# 1       1002        Jacket  Fashion       254             6            1524
# 2       1003    Gym Gloves   Sports        30            10             300
# 3       1004  History Book    Books        45             6             270
# 4       1005   Tennis Ball   Sports       401             1             401
#
#    Order_Date Customer_City
# 0  24/01/2025       Karachi
# 1  01/04/2026      Peshawar
# 2  05/11/2025      Peshawar
# 3  05/01/2026        Lahore
# 4  28/11/2025        Quetta

# %%
df.head(20)
# Out:
#    Product_ID    Product_Name     Category Price_USD Quantity_Sold  \
# 0        1001        Lipstick       Beauty        26             7
# 1        1002          Jacket      Fashion       254             6
# 2        1003      Gym Gloves       Sports        30            10
# 3        1004    History Book        Books        45             6
# 4        1005     Tennis Ball       Sports       401             1
# 5        1006      Coffee Mug         Home       338             8
# 6        1007      Gym Gloves       Sports       102             8
# 7        1008      Gym Gloves       Sports       394             5
# 8        1009        Lipstick       Beauty       381             5
# 9        1010    Science Book        Books       352             3
# 10       1011  Wireless Mouse  Electronics       291            10
# 11       1012           Table         Home       427             9
# 12       1013      Math Guide        Books       126             1
# 13       1014            Lamp         Home        42             2
# 14       1015    Science Book        Books       348             8
# 15       1016     Smart Watch  Electronics       432             4
# 16       1017    Science Book        Books        61             4
# 17       1018    Science Book        Books       202             6
# 18       1019      Headphones  Electronics       250             5
# 19       1020        Football       Sports       410             5
#
#    Total_Sales_USD  Order_Date Customer_City
# 0              182  24/01/2025       Karachi
# 1             1524  01/04/2026      Peshawar
# 2              300  05/11/2025      Peshawar
# 3              270  05/01/2026        Lahore
# 4              401  28/11/2025        Quetta
# 5             2704  06/06/2025        Lahore
# 6              816  25/06/2025     Islamabad
# 7             1970  15/03/2026     Islamabad
# 8             1905  28/02/2025        Lahore
# 9             1056  11/04/2025     Islamabad
# 10            2910  02/09/2025     Islamabad
# 11            3843  17/07/2025       Karachi
# 12             126  17/08/2025     Islamabad
# 13              84  08/09/2025        Quetta
# 14            2784  23/12/2025        Quetta
# 15            1728  20/03/2025       Karachi
# 16             244  11/12/2025        Lahore
# 17            1212  21/01/2025       Karachi
# 18            1250  03/01/2026        Quetta
# 19            2050  25/09/2025     Islamabad

# %%
print(f"Total rows: {len(df)}")
df.head(10)
# Out:
# Total rows: 1000
#   Product_ID  Product_Name Category Price_USD Quantity_Sold Total_Sales_USD  \
# 0       1001      Lipstick   Beauty        26             7             182
# 1       1002        Jacket  Fashion       254             6            1524
# 2       1003    Gym Gloves   Sports        30            10             300
# 3       1004  History Book    Books        45             6             270
# 4       1005   Tennis Ball   Sports       401             1             401
# 5       1006    Coffee Mug     Home       338             8            2704
# 6       1007    Gym Gloves   Sports       102             8             816
# 7       1008    Gym Gloves   Sports       394             5            1970
# 8       1009      Lipstick   Beauty       381             5            1905
# 9       1010  Science Book    Books       352             3            1056
#
#    Order_Date Customer_City
# 0  24/01/2025       Karachi
# 1  01/04/2026      Peshawar
# 2  05/11/2025      Peshawar
# 3  05/01/2026        Lahore
# 4  28/11/2025        Quetta
# 5  06/06/2025        Lahore
# 6  25/06/2025     Islamabad
# 7  15/03/2026     Islamabad
# 8  28/02/2025        Lahore
# 9  11/04/2025     Islamabad

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product_ID       1000 non-null   str
#  1   Product_Name     1000 non-null   str
#  2   Category         1000 non-null   str
#  3   Price_USD        1000 non-null   str
#  4   Quantity_Sold    1000 non-null   str
#  5   Total_Sales_USD  1000 non-null   str
#  6   Order_Date       1000 non-null   str
#  7   Customer_City    1000 non-null   str
# dtypes: str(8)
# memory usage: 62.6 KB
#        Product_ID Product_Name Category Price_USD Quantity_Sold  \
# count        1000         1000     1000      1000          1000
# unique       1000           25        7       426            25
# top          1001  Tennis Ball   Sports       427            10
# freq            1           55      196         9           114
#
#        Total_Sales_USD  Order_Date Customer_City
# count             1000        1000          1000
# unique             770         427             6
# top               1056  05/11/2025     Islamabad
# freq                 5           6           219

# %%
df.isnull().sum()
# Out:
# Product_ID         0
# Product_Name       0
# Category           0
# Price_USD          0
# Quantity_Sold      0
# Total_Sales_USD    0
# Order_Date         0
# Customer_City      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price_USD', 'Quantity_Sold',
#        'Total_Sales_USD', 'Order_Date', 'Customer_City'],
#       dtype='str')

# %%
df.dtypes
df.select_dtypes(include=['number']).columns.tolist()
# Out:
# []

# %%
# Convert numeric columns to actual numbers
df['Price_USD'] = pd.to_numeric(df['Price_USD'], errors='coerce')
df['Quantity_Sold'] = pd.to_numeric(df['Quantity_Sold'], errors='coerce')
df['Total_Sales_USD'] = pd.to_numeric(df['Total_Sales_USD'], errors='coerce')

# Now plot
import matplotlib.pyplot as plt
df['Total_Sales_USD'].plot(kind='bar')
plt.title('Total Sales')
plt.show()
